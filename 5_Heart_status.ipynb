# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
file_path=r"D:\infosys_intern\fitpulse.xlsx"
data=pd.read_excel(file_path)

#checking the heart status
def heart_status(rate):
    if rate < 60:
        return 'Low'
    elif 60 <= rate <= 100:
        return 'Normal'
    else:
        return 'High'
data['Heart_Status'] = data['heart_beat_per_minute'].apply(heart_status)
print(data[['heart_beat_per_minute', 'Heart_Status']].head(15))
# Out:
#     heart_beat_per_minute Heart_Status
# 0                      72       Normal
# 1                      71       Normal
# 2                      70       Normal
# 3                      74       Normal
# 4                      76       Normal
# 5                      70       Normal
# 6                      74       Normal
# 7                      76       Normal
# 8                      78       Normal
# 9                      78       Normal
# 10                     70       Normal
# 11                     71       Normal
# 12                     70       Normal
# 13                     73       Normal
# 14                     70       Normal
